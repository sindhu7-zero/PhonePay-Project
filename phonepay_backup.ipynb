# %%
# !git clone https://github.com/PhonePe/pulse.git
# Out:
# Cloning into 'pulse'...
# Updating files:   8% (768/9029)
# Updating files:   9% (813/9029)
# Updating files:  10% (903/9029)
# Updating files:  11% (994/9029)
# Updating files:  12% (1084/9029)
# Updating files:  13% (1174/9029)
# Updating files:  14% (1265/9029)
# Updating files:  15% (1355/9029)
# Updating files:  16% (1445/9029)
# Updating files:  17% (1535/9029)
# Updating files:  18% (1626/9029)
# Updating files:  18% (1654/9029)
# Updating files:  19% (1716/9029)
# Updating files:  20% (1806/9029)
# Updating files:  21% (1897/9029)
# Updating files:  22% (1987/9029)
# Updating files:  23% (2077/9029)
# Updating files:  24% (2167/9029)
# Updating files:  25% (2258/9029)
# Updating files:  26% (2348/9029)
# Updating files:  27% (2438/9029)
# Updating files:  27% (2485/9029)
# Updating files:  28% (2529/9029)
# Updating files:  29% (2619/9029)
# Updating files:  30% (2709/9029)
# Updating files:  31% (2799/9029)
# Updating files:  32% (2890/9029)
# ...

# %%
# !pip install pandas
# Out:
# ...
#   Using cached pandas-2.3.1-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.3.1-cp313-cp313-win_amd64.whl (11.0 MB)
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.8 MB 2.0 MB/s eta 0:00:07
#    --- ------------------------------------ 1.0/12.8 MB 2.1 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.3/12.8 MB 2.1 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.8/12.8 MB 1.9 MB/s eta 0:00:06
#    -------- ------------------------------- 2.6/12.8 MB 2.3 MB/s eta 0:00:05
#    --------- ------------------------------ 3.1/12.8 MB 2.4 MB/s eta 0:00:04
#    ------------ --------------------------- 3.9/12.8 MB 2.5 MB/s eta 0:00:04
# ...

# %%
pip install SQLAlchemy
# Out:
# ...
#   Using cached sqlalchemy-2.0.41-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# ...
#   Using cached greenlet-3.2.3-cp313-cp313-win_amd64.whl.metadata (4.2 kB)
# ...
#   Using cached typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# Using cached sqlalchemy-2.0.41-cp313-cp313-win_amd64.whl (2.1 MB)
# Using cached greenlet-3.2.3-cp313-cp313-win_amd64.whl (297 kB)
# Using cached typing_extensions-4.14.1-py3-none-any.whl (43 kB)
# ...
#
#    ------------- -------------------------- 1/3 [greenlet]
#    -------------------------- ------------- 2/3 [SQLAlchemy]
#    -------------------------- ------------- 2/3 [SQLAlchemy]
#    -------------------------- ------------- 2/3 [SQLAlchemy]
#    -------------------------- ------------- 2/3 [SQLAlchemy]
#    -------------------------- ------------- 2/3 [SQLAlchemy]
#    -------------------------- ------------- 2/3 [SQLAlchemy]
#    -------------------------- ------------- 2/3 [SQLAlchemy]
#    -------------------------- ------------- 2/3 [SQLAlchemy]
# ...

# %%
pip install psycopg2-binary
# Out:
# ...
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.6 MB 2.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.0/2.6 MB 2.8 MB/s eta 0:00:01
#    -------------------------------- ------- 2.1/2.6 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 3.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

engine = create_engine("postgresql+psycopg2://sindhulocal:7356@localhost:5432/newphonepay")

with engine.connect() as conn:
    print("✅ Connected using psycopg2!")
# Out:
# ✅ Connected using psycopg2!

# %% [markdown]
# ---aggregated-insurance---

# %%
import pandas as pd
import json
import os

# %%
agg_ins_statepath=r"C:\Users\admin\Documents\phonepay_project\PhonePay-Project\pulse\data\aggregated\insurance\country\india\state"
agg_ins_statelist=os.listdir(agg_ins_statepath)

# %%
data
# Out:
# {'success': True,
#  'code': 'SUCCESS',
#  'data': {'from': 1727740800000,
#   'to': 1735344000000,
#   'transactionData': [{'name': 'Insurance',
#     'paymentInstruments': [{'type': 'TOTAL',
#       'count': 91719,
#       'amount': 120602777.0}]}]},
#  'responseTimestamp': 1739974635383}

# %%
agg_ins_data={'state':[],
              'year':[],
              'quarter':[],
              'transaction_type':[],
              'transaction_count':[],
              'transaction_amount':[]}

for state in agg_ins_statelist:
    years=os.listdir(f'{agg_ins_statepath}/{state}')
    for year in years:
        quarter=os.listdir(f'{agg_ins_statepath}/{state}/{year}')
        for qtr in quarter:
            path=(f'{agg_ins_statepath}/{state}/{year}/{qtr}')

            with open(path,'r') as f:
                data=json.load(f)
        
            for i in data['data']['transactionData']:
                transaction_type=i['name']
                count=i['paymentInstruments'][0]['count']
                amount=i['paymentInstruments'][0]['amount']
            #print(district,count,amount)
            #print(district,count,amount,state,year,qtr)
                agg_ins_data['transaction_type'].append(transaction_type)
                agg_ins_data['transaction_count'].append(count)
                agg_ins_data['transaction_amount'].append(amount)
                agg_ins_data['state'].append(state)
                agg_ins_data['year'].append(year)
                agg_ins_data['quarter'].append(int(qtr.strip('.json')))
 
agg_ins_df=pd.DataFrame(agg_ins_data)
agg_ins_df
agg_ins_df.to_sql(name='aggregate_insurance',con=engine,if_exists='append', index=False)
# Out:
# 682

# %% [markdown]
# ---aggregate-transacton----

# %%
data['data']['transactionData']
# Out:
# [{'name': 'Merchant payments',
#   'paymentInstruments': [{'type': 'TOTAL',
#     'count': 655100809,
#     'amount': 389286175909.0}]},
#  {'name': 'Peer-to-peer payments',
#   'paymentInstruments': [{'type': 'TOTAL',
#     'count': 493217788,
#     'amount': 1361927136312.0}]},
#  {'name': 'Recharge & bill payments',
#   'paymentInstruments': [{'type': 'TOTAL',
#     'count': 76043195,
#     'amount': 57534056540.0}]},
#  {'name': 'Financial Services',
#   'paymentInstruments': [{'type': 'TOTAL',
#     'count': 2352084,
#     'amount': 847296537.0}]},
#  {'name': 'Others',
#   'paymentInstruments': [{'type': 'TOTAL',
#     'count': 421806,
#     'amount': 505364108.0}]}]

# %%
agg_tr_statepath=r"C:\Users\admin\Documents\phonepay_project\PhonePay-Project\pulse\data\aggregated\transaction\country\india\state"
agg_tr_statelist=os.listdir(agg_tr_statepath)
agg_tr_data={'state':[],
              'year':[],
              'quarter':[],
              'transaction_type':[],
              'transaction_count':[],
              'transaction_amount':[]}

for state in agg_tr_statelist:
    years=os.listdir(f'{agg_tr_statepath}/{state}')
    for year in years:
        quarter=os.listdir(f'{agg_tr_statepath}/{state}/{year}')
        for qtr in quarter :
            path=(f'{agg_tr_statepath}/{state}/{year}/{qtr}')

            with open(path,'r') as f:
                data=json.load(f)
        
            for i in data['data']['transactionData']:
                transaction_type=i['name']
                count=i['paymentInstruments'][0]['count']
                amount=i['paymentInstruments'][0]['amount']
            #print(district,count,amount)
            #print(district,count,amount,state,year,qtr)
                agg_tr_data['transaction_type'].append(transaction_type)
                agg_tr_data['transaction_count'].append(count)
                agg_tr_data['transaction_amount'].append(amount)
                agg_tr_data['state'].append(state)
                agg_tr_data['year'].append(year)
                agg_tr_data['quarter'].append(int(qtr.strip('.json')))
agg_tr_df=pd.DataFrame(agg_tr_data)
agg_tr_df
agg_tr_df.to_sql(name='aggregate_transaction',con=engine,if_exists='append', index=False)
# Out:
# 34

# %% [markdown]
# ----aggregate-user----

# %%
data
# Out:
# {'success': True,
#  'code': 'SUCCESS',
#  'data': {'aggregated': {'registeredUsers': 34750181, 'appOpens': 1994940763},
#   'usersByDevice': None},
#  'responseTimestamp': 1739974566918}

# %%
agg_user_statepath=r"C:\Users\admin\Documents\phonepay_project\PhonePay-Project\pulse\data\aggregated\user\country\india\state"
agg_user_statelist=os.listdir(agg_user_statepath)
agg_user_data={'state':[],
              'year':[],
              'quarter':[],
              'register_user':[],
              'users_by_device':[],
              'app_opens':[],
              'device_count':[],
              'device_percentage':[]} 

for state in agg_user_statelist:
    years=os.listdir(f'{agg_user_statepath}/{state}')
    for year in years:
        quarter=os.listdir(f'{agg_user_statepath}/{state}/{year}')
        for qtr in quarter :
            path=(f'{agg_user_statepath}/{state}/{year}/{qtr}')
            
            with open(path,'r') as f:
                data=json.load(f)
            try:
                register_user=data['data']['aggregated']['registeredUsers']
                app_open=data['data']['aggregated']['appOpens']
            
               
                for i in data['data']['usersByDevice']:
                    device=i['brand']
                    device_count=i['count']
                    device_percentage=i['percentage']
                    agg_user_data['register_user'].append(register_user)
                    agg_user_data['app_opens'].append(app_open)
                    agg_user_data['users_by_device'].append(device)
                    agg_user_data['device_count'].append(device_count)
                    agg_user_data['device_percentage'].append(device_percentage)
                    agg_user_data['state'].append(state)
                    agg_user_data['year'].append(year)
                    agg_user_data['quarter'].append(int(qtr.strip('.json')))
            except:
                continue  
agg_user_data_df=pd.DataFrame(agg_user_data)  
agg_user_data_df
agg_user_data_df.to_sql(name='aggregate_user',con=engine,if_exists='append', index=False)
# Out:
# 732

# %%
agg_user_statepath=r"C:\Users\admin\Documents\phonepay_project\PhonePay-Project\pulse\data\aggregated\user\country\india\state"
agg_user_statelist=os.listdir(agg_user_statepath)
agg_user_data1={'state':[],
              'year':[],
              'quarter':[],
              'register_user':[],
              'app_opens':[]}
for state in agg_user_statelist:
    years=os.listdir(f'{agg_user_statepath}/{state}')
    for year in years:
        quarter=os.listdir(f'{agg_user_statepath}/{state}/{year}')
        for qtr in quarter :
            path=(f'{agg_user_statepath}/{state}/{year}/{qtr}')
            
            with open(path,'r') as f:
                data=json.load(f)
                try:
                    register_user = data['data']['aggregated']['registeredUsers']
                    app_open = data['data']['aggregated']['appOpens']
                    
                    agg_user_data1['state'].append(state)
                    agg_user_data1['year'].append(year)
                    agg_user_data1['quarter'].append(int(qtr.strip('.json')))
                    agg_user_data1['register_user'].append(register_user)
                    agg_user_data1['app_opens'].append(app_open)
                except:
                    continue

agg_user_data1_df=pd.DataFrame(agg_user_data1)  
agg_user_data1_df
agg_user_data1_df.to_sql(name='aggregate_user_register',con=engine,if_exists='append', index=False)
# Out:
# 8

# %%
data['data']['aggregated']
# Out:
# {'registeredUsers': 34750181, 'appOpens': 1994940763}

# %% [markdown]
# ---map_insurance_hover---

# %%
data
# Out:
# {'success': True,
#  'code': 'SUCCESS',
#  'data': {'hoverDataList': [{'name': 'south twenty four parganas district',
#     'metric': [{'type': 'TOTAL', 'count': 6659, 'amount': 7720038.0}]},
#    {'name': 'purba bardhaman district',
#     'metric': [{'type': 'TOTAL', 'count': 3595, 'amount': 4482879.0}]},
#    {'name': 'uttar dinajpur district',
#     'metric': [{'type': 'TOTAL', 'count': 1730, 'amount': 2115117.0}]},
#    {'name': 'kalimpong district',
#     'metric': [{'type': 'TOTAL', 'count': 137, 'amount': 298205.0}]},
#    {'name': 'murshidabad district',
#     'metric': [{'type': 'TOTAL', 'count': 3214, 'amount': 3386355.0}]},
#    {'name': 'paschim medinipur district',
#     'metric': [{'type': 'TOTAL', 'count': 4155, 'amount': 5405054.0}]},
#    {'name': 'dakshin dinajpur district',
#     'metric': [{'type': 'TOTAL', 'count': 818, 'amount': 948223.0}]},
#    {'name': 'jalpaiguri district',
#     'metric': [{'type': 'TOTAL', 'count': 1622, 'amount': 2307554.0}]},
# ...

# %%
map_insustate_path=r"C:\Users\admin\Documents\phonepay_project\PhonePay-Project\pulse\data\map\insurance\hover\country\india\state"
map_insustate_list=os.listdir(map_insustate_path)
map_ins_data={'state':[],
              'year':[],
              'quarter':[],
              'district':[],
              'transaction_count':[],
              'transaction_amount':[]}

for state in map_insustate_list:
    years=os.listdir(f'{map_insustate_path}/{state}')
    for year in years:
        quarter=os.listdir(f'{map_insustate_path}/{state}/{year}')
        for qtr in quarter :
            path=(f'{map_insustate_path}/{state}/{year}/{qtr}')

            with open(path,'r') as f:
                data=json.load(f)
        
            for i in data['data']['hoverDataList']:
                district=i['name']
                count=i['metric'][0]['count']
                amount=i['metric'][0]['amount']
                #print(district,count,amount)
                #print(district,count,amount,state,year,qtr)
                map_ins_data['district'].append(district)
                map_ins_data['transaction_count'].append(count)
                map_ins_data['transaction_amount'].append(amount)
                map_ins_data['state'].append(state)
                map_ins_data['year'].append(year)
                map_ins_data['quarter'].append(int(qtr.strip('.json')))
 
map_insurance_df=pd.DataFrame(map_ins_data)
map_insurance_df
map_insurance_df.to_sql(name='map_insurance_hover',con=engine,if_exists='append', index=False)
# Out:
# 876

# %% [markdown]
# --- MAP-Insurance-country---

# %%
data
# Out:
# {'success': True,
#  'code': 'SUCCESS',
#  'data': {'meta': {'dataLevel': 'STATE',
#    'gridLevel': 11,
#    'percentiles': {'10.0': 1,
#     '20.0': 2,
#     '40.0': 4,
#     '80.0': 18,
#     '90.0': 34,
#     '99.5': 706,
#     '50.0': 6,
#     '30.0': 3,
#     '60.0': 8}},
#   'data': {'columns': ['lat', 'lng', 'metric', 'label'],
#    'data': [[22.52223941747976, 88.36763925689654, 2352.0, 'kolkata district'],
#     [22.56950724146514, 88.32878957469845, 2167.0, 'howrah district'],
#     [22.56990429404908,
#      88.36763925689654,
#      1938.0,
#      'north twenty four parganas district'],
#     [22.521843022856768, 88.32878957469845, 1886.0, 'kolkata district'],
#     [22.57029166423423,
#      88.40645404103664,
#      1704.0,
#      'north twenty four parganas district'],
#     [22.61795526890876,
#      88.40645404103664,
#      1642.0,
#      'north twenty four parganas district'],
#     [22.474572724430853, 88.36763925689654, 1495.0, 'kolkata district'],
# ...

# %%
m_i_c_statepath=r"C:\Users\admin\Documents\phonepay_project\PhonePay-Project\pulse\data\map\insurance\country\india\state"
m_i_c_statelist=os.listdir(m_i_c_statepath)
m_i_c_data={'state':[],
            'year':[],
            'qtr':[],
            'lat':[],
            'lng':[],
            'matric':[],
            'label':[],
            'datalevel':[],
            'gridlevel':[] }

for state in m_i_c_statelist:
    years=os.listdir(f'{m_i_c_statepath}/{state}')
    for year in years:
        quarter=os.listdir(f'{m_i_c_statepath}/{state}/{year}')
        for qtr in quarter:
            m_i_c_path=(f'{m_i_c_statepath}/{state}/{year}/{qtr}')
            
            with open(m_i_c_path, 'r') as f:
                data=json.load(f)
            
           
            datalevel=data['data']['meta']['dataLevel']
            gridLevel=data['data']['meta']['gridLevel']
            

            for i in data['data']['data']['data']:
                m_i_c_data['state'].append(state)
                m_i_c_data['year'].append(year)
                m_i_c_data['qtr'].append(int(qtr.strip('.json')))
                m_i_c_data['lat'].append(i[0])
                m_i_c_data['lng'].append(i[1])
                m_i_c_data['matric'].append(i[2])
                m_i_c_data['label'].append(i[3])
                m_i_c_data['datalevel'].append(datalevel)
                m_i_c_data['gridlevel'].append(gridLevel)

m_i_c_data_df=pd.DataFrame(m_i_c_data)
m_i_c_data_df
m_i_c_data_df.to_sql(name='map_insurance_country',con=engine,if_exists='append', index=False)
# Out:
# 137

# %% [markdown]
# ---MAP -transaction

# %%
map_state_path=r"C:\Users\admin\Documents\phonepay_project\PhonePay-Project\pulse\data\map\transaction\hover\country\india\state"
map_state_list=os.listdir(map_state_path)
map_trans_data={'state':[],'year':[],'quarter':[],'district':[],'transacion_count':[],'transaction_amount':[]}

for state in map_state_list:
   years=os.listdir(f'{map_state_path}/{state}')
   for year in years:
      quarter=os.listdir(f'{map_state_path}/{state}/{year}')
      for qtr in quarter:
         path=f'{map_state_path}/{state}/{year}/{qtr}'
         #print(path)

         with open(path,'r') as f:
            data=json.load(f)
        
         for i in data['data']['hoverDataList']: 
            district=i['name']
            count=i['metric'][0 ]['count']
            amount=i['metric'][0]['amount']
               #print(district,count,amount,state,year,qtr)
            map_trans_data['district'].append(district)
            map_trans_data['transacion_count'].append(count)
            map_trans_data['transaction_amount'].append(amount)
            map_trans_data['state'].append(state)
            map_trans_data['year'].append(year)
            map_trans_data['quarter'].append(int(qtr.strip('.json')))
map_transaction_df=pd.DataFrame(map_trans_data)
map_transaction_df
map_transaction_df.to_sql(name='map_transaction',con=engine,if_exists='append', index=False)
# Out:
# 604

# %% [markdown]
# ---map_user--

# %%
m_u_statepath=r"C:\Users\admin\Documents\phonepay_project\PhonePay-Project\pulse\data\map\user\hover\country\india\state"
m_u_statelist=os.listdir(m_u_statepath)
map_user_data={'state':[],
              'year':[],
              'quarter':[],
              'district':[],
              'count':[],
              'appopen':[]}

for state in m_u_statelist:
    years=os.listdir(f'{m_u_statepath}/{state}')
    for year in years:
        quarter=os.listdir(f'{m_u_statepath}/{state}/{year}')
        for qtr in quarter :
            path=(f'{m_u_statepath}/{state}/{year}/{qtr}')

            with open(path,'r') as f:
                data=json.load(f)
        
            for i,j in data['data']['hoverData'].items():
                district3=i
                reg_user=j['registeredUsers']
                app_count=j['appOpens']
            #print(district,count,amount)
            #print(district,count,amount,state,year,qtr)
                map_user_data['district'].append(district3)
                map_user_data['count'].append(reg_user)
                map_user_data['appopen'].append(app_count)
                map_user_data['state'].append(state)
                map_user_data['year'].append(year)
                map_user_data['quarter'].append(int(qtr.strip('.json')))
map_user_df=pd.DataFrame(map_user_data)
map_user_df
map_user_df.to_sql(name='map_user',con=engine,if_exists='append', index=False)
# Out:
# 608

# %% [markdown]
# ---Top-insurance----

# %%
top_ins_statepath=r"C:\Users\admin\Documents\phonepay_project\PhonePay-Project\pulse\data\top\insurance\country\india\state"
top_ins_statelist=os.listdir(top_ins_statepath)
top_ins_dis_data={
                'state':[],
                'year':[],
                'quarter':[],
                'dis_name':[],
                'transaction_count':[],
                'transaction_amount':[]}
                
for state in top_ins_statelist:
    years=os.listdir(f'{top_ins_statepath}/{state}')
    for year in years:
        quarter=os.listdir(f'{top_ins_statepath}/{state}/{year}')
        for qtr in quarter:
            path=f'{top_ins_statepath}/{state}/{year}/{qtr}'
                
            with open(path, 'r') as f:
                data=json.load(f)
                try:
                    for i in data['data']['districts']:
                        state_en=i['entityName']
                        count=i['metric']['count']
                        amount=i['metric']['amount']
                        top_ins_dis_data['dis_name'].append(state_en)
                        top_ins_dis_data['transaction_count'].append(count)
                        top_ins_dis_data['transaction_amount'].append(amount)
                        top_ins_dis_data['state'].append(state)
                        top_ins_dis_data['year'].append(year)
                        top_ins_dis_data['quarter'].append(int(qtr.strip('.json')))
                except:
                    continue     

top_ins_dis_data_df=pd.DataFrame(top_ins_dis_data)
top_ins_dis_data_df   
top_ins_dis_data_df.to_sql(name='top_insurance_district',con=engine,if_exists='append', index=False)
# Out:
# 608

# %%
top_ins_pin_data={
                'state':[],
                'year':[],
                'quarter':[],
                'entity_name':[],
                'transaction_count':[],
                'transaction_amount':[]}
                
for state in top_ins_statelist:
    years=os.listdir(f'{top_ins_statepath}/{state}')
    for year in years:
        quarter=os.listdir(f'{top_ins_statepath}/{state}/{year}')
        for qtr in quarter:
            path=f'{top_ins_statepath}/{state}/{year}/{qtr}'
                
            with open(path, 'r') as f:
                data=json.load(f)
                try:
                    for i in data['data']['pincodes']:
                        state_en=i['entityName']
                        count=i['metric']['count']
                        amount=i['metric']['amount']
                        top_ins_pin_data['entity_name'].append(state_en)
                        top_ins_pin_data['transaction_count'].append(count)
                        top_ins_pin_data['transaction_amount'].append(amount)
                        top_ins_pin_data['state'].append(state)
                        top_ins_pin_data['year'].append(year)
                        top_ins_pin_data['quarter'].append(int(qtr.strip('.json')))
                except:
                    continue                                       
              

top_ins_pin_data_df=pd.DataFrame(top_ins_pin_data)
top_ins_pin_data_df
                         
top_ins_pin_data_df.to_sql(name='top_insurance_pincode',con=engine,if_exists='append', index=False)
# Out:
# 668

# %% [markdown]
# ----top-transaction------

# %%
top_trans_statepath=r'C:\Users\admin\Documents\phonepay_project\PhonePay-Project\pulse\data\top\transaction\country\india\state' 
top_trans_statelist=os.listdir(top_trans_statepath)
top_trans_dis_data={'state':[],
                    'year':[],
                    'quarter':[],
                    'entity_name':[],
                    'transaction_count':[],
                    'transaction_amount':[]
                    }
for state in top_trans_statelist:
    years=os.listdir(f'{top_trans_statepath}/{state}')
    for year in years:
        quarter=os.listdir(f'{top_trans_statepath}/{state}/{year}') 
        for qtr in quarter:
            top_trans_path=(f'{top_trans_statepath}/{state}/{year}/{qtr}') 

            with open(top_trans_path, 'r') as f:
                data=json.load(f)

            for i in data['data']['districts']:
                en_name=i['entityName']
                count=i['metric']['count']
                amount=i['metric']['amount']
                top_trans_dis_data['entity_name'].append(en_name)
                top_trans_dis_data['transaction_count'].append(count)
                top_trans_dis_data['transaction_amount'].append(amount)
                top_trans_dis_data['state'].append(state)
                top_trans_dis_data['year'].append(year)
                top_trans_dis_data['quarter'].append(int(qtr.strip('.json')))

top_trans_dis_data_df=pd.DataFrame(top_trans_dis_data)
top_trans_dis_data_df
top_trans_dis_data_df.to_sql(name='top_transaction_district',con=engine,if_exists='append', index=False)
# Out:
# 296

# %%
top_trans_pin_data={'state':[],
                    'year':[],
                    'quarter':[],
                    'entity_name':[],
                    'transaction_count':[],
                    'transaction_amount':[]
                    }
for state in top_trans_statelist:
    years=os.listdir(f'{top_trans_statepath}/{state}')
    for year in years:
        quarter=os.listdir(f'{top_trans_statepath}/{state}/{year}') 
        for qtr in quarter:
            top_trans_path=(f'{top_trans_statepath}/{state}/{year}/{qtr}') 

            with open(top_trans_path, 'r') as f:
                data=json.load(f)

            for i in data['data']['pincodes']:
                en_name=i['entityName']
                count=i['metric']['count']
                amount=i['metric']['amount']
                top_trans_pin_data['entity_name'].append(en_name)
                top_trans_pin_data['transaction_count'].append(count)
                top_trans_pin_data['transaction_amount'].append(amount)
                top_trans_pin_data['state'].append(state)
                top_trans_pin_data['year'].append(year)
                top_trans_pin_data['quarter'].append(int(qtr.strip('.json')))

top_trans_pin_data_df=pd.DataFrame(top_trans_pin_data)
top_trans_pin_data_df
top_trans_pin_data_df.to_sql(name='top_transaction_pincode',con=engine,if_exists='append', index=False)
# Out:
# 999

# %% [markdown]
# ----top-user-----

# %%
top_user_state_path=r"C:\Users\admin\Documents\phonepay_project\PhonePay-Project\pulse\data\top\user\country\india\state"
top_user_state_list=os.listdir(top_user_state_path)
top_user_dis_data={'state':[],
                    'year':[],
                    'qtr':[],
                    'dis_name':[],
                    'reg_user':[]
                    }
for state in top_user_state_list:
    years=os.listdir(f'{top_user_state_path}/{state}')
    for year in years:
        quarter=os.listdir(f'{top_user_state_path}/{state}/{year}') 
        for qtr in quarter:
            top_trans_path=(f'{top_user_state_path}/{state}/{year}/{qtr}') 

            with open(top_trans_path, 'r') as f:
                data=json.load(f)

            for i in data['data']['districts']:
                name=i['name']
                reg_user=i['registeredUsers']
                top_user_dis_data['dis_name'].append(name)
                top_user_dis_data['reg_user'].append(reg_user)
                top_user_dis_data['state'].append(state)
                top_user_dis_data['year'].append(year)
                top_user_dis_data['qtr'].append(int(qtr.strip('.json')))

top_user_dis_data_df=pd.DataFrame(top_user_dis_data)
top_user_dis_data_df
top_user_dis_data_df.to_sql(name='top_user_dis_data',con=engine,if_exists='append', index=False)
# Out:
# 296

# %%
top_user_pin_data={'state':[],
                    'year':[],
                    'quarter':[],
                    'entity_name':[],
                    'reg_user':[]
                    }
for state in top_user_state_list:
    years=os.listdir(f'{top_user_state_path}/{state}')
    for year in years:
        quarter=os.listdir(f'{top_user_state_path}/{state}/{year}') 
        for qtr in quarter:
            top_trans_path=(f'{top_user_state_path}/{state}/{year}/{qtr}') 

            with open(top_trans_path, 'r') as f:
                data=json.load(f)

            for i in data['data']['pincodes']:
                name=i['name']
                reg_user=i['registeredUsers']
                top_user_pin_data['entity_name'].append(name)
                top_user_pin_data['reg_user'].append(reg_user)
                top_user_pin_data['state'].append(state)
                top_user_pin_data['year'].append(year)
                top_user_pin_data['quarter'].append(int(qtr.strip('.json')))

top_user_pin_data_df=pd.DataFrame(top_user_pin_data)
top_user_pin_data_df
top_user_pin_data_df.to_sql(name='top_user_pin_data',con=engine,if_exists='append', index=False)
top_user_pin_data_df
# Out:
#                           state  year  quarter entity_name  reg_user
# 0     andaman-&-nicobar-islands  2018        1      744103      1608
# 1     andaman-&-nicobar-islands  2018        1      744101      1108
# 2     andaman-&-nicobar-islands  2018        1      744105      1075
# 3     andaman-&-nicobar-islands  2018        1      744102      1006
# 4     andaman-&-nicobar-islands  2018        1      744104       272
# ...                         ...   ...      ...         ...       ...
# 9995                west-bengal  2024        4      733134    169596
# 9996                west-bengal  2024        4      700059    169448
# 9997                west-bengal  2024        4      711302    146034
# 9998                west-bengal  2024        4      700150    142151
# 9999                west-bengal  2024        4      711106    142077
#
# [10000 rows x 5 columns]

# %%
from geopy.geocoders import Nominatim

# %%
geolocator = Nominatim(user_agent="State_map")
location = geolocator.geocode("andaman-&-nicobar-islands")
location
# Out:
# Location(Nicobar Islands, Great Nicobar, Nicobar, Andaman and Nicobar Islands, India, (7.0000167, 93.8110528, 0.0))

# %%
import time

# %%
state_lat_lon={'state':[],'lat':[],'lon':[]}
for i in top_user_pin_data_df['state'].unique():
    location = geolocator.geocode(i)
    lat=location.latitude
    lon=location.longitude
    state_lat_lon['state'].append(i)
    state_lat_lon['lat'].append(lat)
    state_lat_lon['lon'].append(lon)
    print(i,lat,lon)
    time.sleep(1)
# Out:
# andaman-&-nicobar-islands 7.0000167 93.8110528
# andhra-pradesh 15.9240905 80.1863809
# arunachal-pradesh 28.0937702 94.5921326
# assam 26.4073841 93.2551303
# bihar 25.6440845 85.906508
# chandigarh 30.7334421 76.7797143
# chhattisgarh 21.6637359 81.8406351
# dadra-&-nagar-haveli-&-daman-&-diu 20.7137783 70.9853635
# delhi 28.6328027 77.2197713
# goa 15.3004543 74.0855134
# gujarat 22.3850051 71.745261
# haryana 29.0 76.0
# himachal-pradesh 31.9292352 77.1828462
# jammu-&-kashmir 33.6649297 75.1629584
# jharkhand 23.4559809 85.2557301
# karnataka 14.5203896 75.7223521
# kerala 10.3528744 76.5120396
# ladakh 33.9456407 77.6568576
# lakshadweep 10.3337313 72.9205386
# madhya-pradesh 23.8143419 77.5340719
# maharashtra 18.9068356 75.6741579
# manipur 24.7208818 93.9229386
# meghalaya 25.5379432 91.2999102
# mizoram 23.2146169 92.8687612
# nagaland 26.1630556 94.5884911
# odisha 20.5431241 84.6897321
# puducherry 10.9156489 79.8069488
# punjab 30.9293211 75.5004841
# ...

# %%
import pandas as pd

# %%
state_df=pd.DataFrame(state_lat_lon)
state_df
# Out:
#                                  state        lat        lon
# 0            andaman-&-nicobar-islands   7.000017  93.811053
# 1                       andhra-pradesh  15.924091  80.186381
# 2                    arunachal-pradesh  28.093770  94.592133
# 3                                assam  26.407384  93.255130
# 4                                bihar  25.644085  85.906508
# 5                           chandigarh  30.733442  76.779714
# 6                         chhattisgarh  21.663736  81.840635
# 7   dadra-&-nagar-haveli-&-daman-&-diu  20.713778  70.985364
# 8                                delhi  28.632803  77.219771
# 9                                  goa  15.300454  74.085513
# 10                             gujarat  22.385005  71.745261
# 11                             haryana  29.000000  76.000000
# 12                    himachal-pradesh  31.929235  77.182846
# 13                     jammu-&-kashmir  33.664930  75.162958
# ...

# %%
pd.merge(agg_tr_df,state_df,on='state')
# Out:
#                           state  year  quarter          transaction_type  \
# 0     andaman-&-nicobar-islands  2018        1  Recharge & bill payments
# 1     andaman-&-nicobar-islands  2018        1     Peer-to-peer payments
# 2     andaman-&-nicobar-islands  2018        1         Merchant payments
# 3     andaman-&-nicobar-islands  2018        1        Financial Services
# 4     andaman-&-nicobar-islands  2018        1                    Others
# ...                         ...   ...      ...                       ...
# 5029                west-bengal  2024        4         Merchant payments
# 5030                west-bengal  2024        4     Peer-to-peer payments
# 5031                west-bengal  2024        4  Recharge & bill payments
# 5032                west-bengal  2024        4        Financial Services
# 5033                west-bengal  2024        4                    Others
#
#       transaction_count  transaction_amount        lat        lon
# ...

# %%
state_df = pd.DataFrame(state_lat_lon)
state_df.to_csv("state_lat_lon.csv", index=False)
